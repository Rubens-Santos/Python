# %% [markdown]
# <a href="https://colab.research.google.com/github/Rubens-Santos/Python/blob/master/Cota%C3%A7%C3%B5es.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importando as bibliotecas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader.data as web

# !pip install yfinance --upgrade --no-cache-dir #instalando a biblioteca yfinances
import yfinance as yf
yf.pdr_override()
# Out:
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.54-py2.py3-none-any.whl size=22409 sha256=70242373f8ff72f7c91a920634afd2daa876b1faa55784dd07d4adb5c443a32f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7f1l08ku/wheels/f9/e3/5b/ec24dd2984b12d61e0abf26289746c2436a0e7844f26f2515c
# Successfully built yfinance
# ...

# %% [markdown]
# # Obtendo os dados da Bolsa de valores

# %%
ibov = web.get_data_yahoo('^BVSP')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ibov.head()
# Out:
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 1993-04-27  24.799999  25.400000  24.500000  24.500000  24.500000       0
# 1993-04-28  24.500000  24.600000  23.700001  24.299999  24.299999       0
# 1993-04-29  24.299999  24.799999  23.700001  23.700001  23.700001       0
# 1993-04-30  23.700001  24.200001  23.700001  24.100000  24.100000       0
# 1993-05-03  24.100000  24.400000  23.799999  24.100000  24.100000       0

# %%
ibov.tail()
# Out:
#                Open     High      Low    Close  Adj Close    Volume
# Date
# 2020-03-11  92202.0  92202.0  80796.0  85171.0    85171.0  11786900
# 2020-03-12  85103.0  85103.0  68488.0  72583.0    72583.0  12008700
# 2020-03-13  72621.0  83758.0  72621.0  82678.0    82678.0  15766300
# 2020-03-16  82565.0  82565.0  70855.0  71168.0    71168.0  12847800
# 2020-03-17  71178.0  77255.0  70783.0  74617.0    74617.0  14945900

# %%
ibov["Close"].plot(figsize=(22,8))

# %%
ibov["Open"].plot(figsize=(20,6))

# %% [markdown]
# # Puxando os dados da ação ITUSA4 ultimos 10 Anos

# %%
itusa = web.get_data_yahoo('ITSA4.SA')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
itusa.tail()
# Out:
#              Open   High   Low  Close  Adj Close    Volume
# Date
# 2020-03-11  10.89  11.00  9.87  10.40      10.40  45533600
# 2020-03-12   9.25   9.85  9.07   9.27       9.27  52155000
# 2020-03-13  10.50  10.56  9.27  10.20      10.20  58134100
# 2020-03-16   9.15   9.79  9.10   9.10       9.10  51916900
# 2020-03-17   0.00   0.00  0.00   9.54       9.54         0

# %%
itusa["Close"].plot(figsize=(18,6))
ambev["Close"].plot(figsize=(18,6))
oi["Close"].plot(figsize=(18,6))

# %%
ambev = web.get_data_yahoo('ABEV3.SA')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ambev.tail()
# Out:
#              Open   High    Low  Close  Adj Close    Volume
# Date
# 2020-03-11  14.14  14.33  12.90  13.75      13.75  39788900
# 2020-03-12  12.48  12.68  11.39  11.58      11.58  36313400
# 2020-03-13  12.60  13.09  11.64  12.70      12.70  51339000
# 2020-03-16  11.39  11.77  10.43  11.03      11.03  52067300
# 2020-03-17   0.00   0.00   0.00  11.69      11.69         0

# %%
ambev["Close"].plot(figsize=(20,6))

# %%
oi = web.get_data_yahoo('OIBR4.SA')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
oi.tail()
# Out:
#             Open  High   Low  Close  Adj Close   Volume
# Date
# 2020-03-11  1.38  1.44  1.15   1.31       1.31  7612500
# 2020-03-12  1.22  1.24  1.14   1.20       1.20  4204000
# 2020-03-13  1.31  1.32  1.18   1.24       1.24  4985600
# 2020-03-16  1.19  1.19  1.11   1.12       1.12  2880600
# 2020-03-17  0.00  0.00  0.00   1.11       1.11        0

# %%
oi["Close"].plot(figsize=(20,6))
